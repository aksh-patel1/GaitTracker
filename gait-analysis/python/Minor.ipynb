# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
base_path = "drive/MyDrive/minor_project/gait_analysis/Final_data/"

# %% [markdown]
# # User 1

# %%
dframe = pd.read_csv(base_path + "serial_20230512_004013.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe.head()
# Out:
# <ipython-input-28-d778f6754ca7>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_004013.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp     Magnitude
# 0  00:39:46.420  11.97,198098
# 1  00:39:46.638  11.88,198300
# 2  00:39:46.842  15.00,198502
# 3  00:39:47.063  13.15,198704
# 4  00:39:47.237  16.73,198906

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude     Mag
# 0   00:39:46.420     11.97  198098
# 1   00:39:46.638     11.88  198300
# 2   00:39:46.842     15.00  198502
# 3   00:39:47.063     13.15  198704
# 4   00:39:47.237     16.73  198906
# ..           ...       ...     ...
# 88  00:40:04.213     20.47  215874
# 89  00:40:04.403     10.07  216076
# 90  00:40:04.607     29.62  216278
# 91  00:40:04.816     16.03  216480
# 92  00:40:05.006     11.89  216682
#
# [93 rows x 3 columns]

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:39:46.420     11.97
# 1   00:39:46.638     11.88
# 2   00:39:46.842     15.00
# 3   00:39:47.063     13.15
# 4   00:39:47.237     16.73
# ..           ...       ...
# 88  00:40:04.213     20.47
# 89  00:40:04.403     10.07
# 90  00:40:04.607     29.62
# 91  00:40:04.816     16.03
# 92  00:40:05.006     11.89
#
# [93 rows x 2 columns]

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 2

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002239.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe.head()
# Out:
# <ipython-input-46-b34c027ff13b>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002239.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp    Magnitude
# 0  00:22:17.366  15.36,48730
# 1  00:22:17.876  25.79,49232
# 2  00:22:18.356  13.08,49734
# 3  00:22:18.858  17.26,50236
# 4  00:22:19.393  15.65,50738

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:22:17.366     15.36  48730
# 1   00:22:17.876     25.79  49232
# 2   00:22:18.356     13.08  49734
# 3   00:22:18.858     17.26  50236
# 4   00:22:19.393     15.65  50738
# 5   00:22:19.890     12.86  51240
# 6   00:22:20.391     14.47  51742
# 7   00:22:20.882     13.24  52244
# 8   00:22:21.388     13.48  52746
# 9   00:22:21.863     15.65  53248
# 10  00:22:22.405     12.61  53750
# 11  00:22:22.890     18.91  54252
# 12  00:22:23.408     22.76  54754
# 13  00:22:23.913     13.91  55256
# 14  00:22:24.394     15.27  55758
# 15  00:22:24.892     23.63  56260
# 16  00:22:25.399     12.86  56762
# 17  00:22:25.905     12.68  57264
# 18  00:22:26.429     13.13  57766
# 19  00:22:26.912     21.62  58268
# 20  00:22:27.392     12.77  58770
# 21  00:22:27.892     10.87  59272
# 22  00:22:28.414     14.59  59774
# 23  00:22:28.922     23.52  60276
# 24  00:22:29.429     29.49  60778
# 25  00:22:29.916     16.35  61280
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:22:17.366     15.36
# 1   00:22:17.876     25.79
# 2   00:22:18.356     13.08
# 3   00:22:18.858     17.26
# 4   00:22:19.393     15.65
# 5   00:22:19.890     12.86
# 6   00:22:20.391     14.47
# 7   00:22:20.882     13.24
# 8   00:22:21.388     13.48
# 9   00:22:21.863     15.65
# 10  00:22:22.405     12.61
# 11  00:22:22.890     18.91
# 12  00:22:23.408     22.76
# 13  00:22:23.913     13.91
# 14  00:22:24.394     15.27
# 15  00:22:24.892     23.63
# 16  00:22:25.399     12.86
# 17  00:22:25.905     12.68
# 18  00:22:26.429     13.13
# 19  00:22:26.912     21.62
# 20  00:22:27.392     12.77
# 21  00:22:27.892     10.87
# 22  00:22:28.414     14.59
# 23  00:22:28.922     23.52
# 24  00:22:29.429     29.49
# 25  00:22:29.916     16.35
# 26  00:22:30.414     27.29
# 27  00:22:30.920     13.04
# 28  00:22:31.437     14.49
# 29  00:22:31.935     11.96
# 30  00:22:32.443     21.46
# 31  00:22:32.936     16.40
# 32  00:22:33.428     15.27
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 3

# %%
dframe = pd.read_csv(base_path + "serial_20230512_004658.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe.head()
# Out:
# <ipython-input-55-d446ebf3efc7>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_004658.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp    Magnitude
# 0  00:46:33.588  11.00,33659
# 1  00:46:33.765  11.17,33861
# 2  00:46:33.967  12.65,34063
# 3  00:46:34.186  12.30,34265
# 4  00:46:34.401  12.54,34467

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:46:33.588     11.00  33659
# 1   00:46:33.765     11.17  33861
# 2   00:46:33.967     12.65  34063
# 3   00:46:34.186     12.30  34265
# 4   00:46:34.401     12.54  34467
# ..           ...       ...    ...
# 89  00:46:51.557     12.91  51637
# 90  00:46:51.774     11.07  51839
# 91  00:46:51.954     10.78  52041
# 92  00:46:52.153     10.61  52243
# 93  00:46:52.363     15.51  52445
#
# [94 rows x 3 columns]

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:46:33.588     11.00
# 1   00:46:33.765     11.17
# 2   00:46:33.967     12.65
# 3   00:46:34.186     12.30
# 4   00:46:34.401     12.54
# ..           ...       ...
# 89  00:46:51.557     12.91
# 90  00:46:51.774     11.07
# 91  00:46:51.954     10.78
# 92  00:46:52.153     10.61
# 93  00:46:52.363     15.51
#
# [94 rows x 2 columns]

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 4

# %%
dframe = pd.read_csv(base_path + "serial_20230512_003913.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe.head()
# Out:
# <ipython-input-90-c2f53c4f3dd1>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_003913.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp     Magnitude
# 0  00:38:46.615  11.32,138509
# 1  00:38:46.802  11.36,138711
# 2  00:38:47.017  11.50,138913
# 3  00:38:47.212  11.58,139115
# 4  00:38:47.416  11.58,139317

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude     Mag
# 0   00:38:46.615     11.32  138509
# 1   00:38:46.802     11.36  138711
# 2   00:38:47.017     11.50  138913
# 3   00:38:47.212     11.58  139115
# 4   00:38:47.416     11.58  139317
# ..           ...       ...     ...
# 68  00:39:00.343     19.62  152245
# 69  00:39:00.538     11.40  152447
# 70  00:39:00.757     29.09  152649
# 71  00:39:00.953     15.34  152851
# 72  00:39:01.147      8.30  153053
#
# [73 rows x 3 columns]

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:38:46.615     11.32
# 1   00:38:46.802     11.36
# 2   00:38:47.017     11.50
# 3   00:38:47.212     11.58
# 4   00:38:47.416     11.58
# ..           ...       ...
# 68  00:39:00.343     19.62
# 69  00:39:00.538     11.40
# 70  00:39:00.757     29.09
# 71  00:39:00.953     15.34
# 72  00:39:01.147      8.30
#
# [73 rows x 2 columns]

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 5

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User A: Priyank

# %% [markdown]
# ## Normal

# %%
dframe = pd.read_csv(base_path + "sub1_norm.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe.head()
# Out:
# <ipython-input-43-0228a312e536>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "sub1_norm.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp    Magnitude
# 0  00:47:06.087  10.88,66181
# 1  00:47:06.301  11.29,66383
# 2  00:47:06.502  11.27,66585
# 3  00:47:06.691  10.43,66787
# 4  00:47:06.891  10.79,66989

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#         Timestamp Magnitude    Mag
# 0    00:47:06.087     10.88  66181
# 1    00:47:06.301     11.29  66383
# 2    00:47:06.502     11.27  66585
# 3    00:47:06.691     10.43  66787
# 4    00:47:06.891     10.79  66989
# ..            ...       ...    ...
# 97   00:47:25.688      5.53  85775
# 98   00:47:25.902     12.58  85977
# 99   00:47:26.092      8.93  86179
# 100  00:47:26.298     11.90  86381
# 101  00:47:26.501     10.49  86583
#
# [102 rows x 3 columns]

# %%
df.drop('Mag', axis='columns')
# Out:
#         Timestamp Magnitude
# 0    00:47:06.087     10.88
# 1    00:47:06.301     11.29
# 2    00:47:06.502     11.27
# 3    00:47:06.691     10.43
# 4    00:47:06.891     10.79
# ..            ...       ...
# 97   00:47:25.688      5.53
# 98   00:47:25.902     12.58
# 99   00:47:26.092      8.93
# 100  00:47:26.298     11.90
# 101  00:47:26.501     10.49
#
# [102 rows x 2 columns]

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# ## Abnormal

# %%
dframe_ab = pd.read_csv(base_path + "sub1_abnorm.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
dframe_ab.head()
# Out:
# <ipython-input-50-87a05cdf21fb>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe_ab = pd.read_csv(base_path + "sub1_abnorm.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"])
#       Timestamp     Magnitude
# 0  00:47:39.221   10.99,99308
# 1  00:47:39.423   11.05,99510
# 2  00:47:39.634   10.77,99712
# 3  00:47:39.826   10.76,99914
# 4  00:47:40.021  10.89,100116

# %%
df_ab = dframe_ab

# %%
df_ab[['Magnitude', 'Mag']] = df_ab.Magnitude.str.split(",", expand=True)

# %%
df_ab
# Out:
#         Timestamp Magnitude     Mag
# 0    00:47:39.221     10.99   99308
# 1    00:47:39.423     11.05   99510
# 2    00:47:39.634     10.77   99712
# 3    00:47:39.826     10.76   99914
# 4    00:47:40.021     10.89  100116
# ..            ...       ...     ...
# 129  00:48:05.283     12.56  125366
# 130  00:48:05.482      7.01  125568
# 131  00:48:05.678     11.62  125770
# 132  00:48:05.886     11.20  125972
# 133  00:48:06.080     11.31  126174
#
# [134 rows x 3 columns]

# %%
df_ab.drop('Mag', axis='columns')
# Out:
#         Timestamp Magnitude
# 0    00:47:39.221     10.99
# 1    00:47:39.423     11.05
# 2    00:47:39.634     10.77
# 3    00:47:39.826     10.76
# 4    00:47:40.021     10.89
# ..            ...       ...
# 129  00:48:05.283     12.56
# 130  00:48:05.482      7.01
# 131  00:48:05.678     11.62
# 132  00:48:05.886     11.20
# 133  00:48:06.080     11.31
#
# [134 rows x 2 columns]

# %%
df_ab['Magnitude'] = pd.to_numeric(df_ab.Magnitude)

# %%
df_ab.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# ## Normal Vs Abnormal

# %%
plt.plot(df_ab.Magnitude, label = "line 1")
plt.show()

# %%
plt.plot(df.Magnitude, label = "line 1", color='r')
plt.show()

# %%
plt.plot(df.Magnitude, label = "Normal")
plt.plot(df_ab.Magnitude, label = "Abnormal")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))

# Creating plot
plt.boxplot(df.Magnitude)
#plt.boxplot(df_ab.Magnitude)

# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))

# Creating plot
plt.boxplot(df_ab.Magnitude)
#plt.boxplot(df_ab.Magnitude)

# show plot
plt.show()

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [9, 6]
plt.rcParams["figure.autolayout"] = True

# Pandas dataframe
data = pd.DataFrame({"Normal": df.Magnitude, "Abnormal": df_ab.Magnitude})

# Plot the dataframe
ax = data[['Normal', 'Abnormal']].plot(kind='box', title='boxplot')

# Display the plot
plt.show()

# %% [markdown]
# # User 5

# %%
dframe = pd.read_csv(base_path + "serial_20230512_001611.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-4-a3516b33c1b3>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_001611.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-a3516b33c1b3> in <cell line: 1>()
# ----> 1 dframe = pd.read_csv(base_path + "serial_20230512_001611.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       2 dframe.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
# ...

# %%
df = dframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1c3bd192a0e6> in <cell line: 1>()
# ----> 1 df = dframe
#
# NameError: name 'dframe' is not defined

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df

# %%
df.drop('Mag', axis='columns')

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))

# %% [markdown]
# # User 6

# %%
dframe = pd.read_csv(base_path + "serial_20230512_001742.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 7

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002046.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 8

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 9

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002239.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 10

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002411.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 11

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002445.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 12

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002531.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 13

# %%
dframe = pd.read_csv(base_path + "serial_20230512_002820.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >

# %% [markdown]
# # User 14

# %%
dframe = pd.read_csv(base_path + "serial_20230512_003311.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
dframe.head()
# Out:
# <ipython-input-83-62a6b17a10c0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dframe = pd.read_csv(base_path + "serial_20230512_002214.txt", sep=' ', header=None, skipfooter=1, names=["Timestamp", "Magnitude"],skiprows=[0,1])
#       Timestamp    Magnitude
# 0  00:21:44.740  12.73,16100
# 1  00:21:45.249  12.89,16602
# 2  00:21:45.751  11.24,17104
# 3  00:21:46.223  12.68,17606
# 4  00:21:46.730  13.66,18108

# %%
df = dframe

# %%
df[['Magnitude', 'Mag']] = df.Magnitude.str.split(",", expand=True)

# %%
df
# Out:
#        Timestamp Magnitude    Mag
# 0   00:21:44.740     12.73  16100
# 1   00:21:45.249     12.89  16602
# 2   00:21:45.751     11.24  17104
# 3   00:21:46.223     12.68  17606
# 4   00:21:46.730     13.66  18108
# 5   00:21:47.266     22.93  18610
# 6   00:21:47.774     12.59  19112
# 7   00:21:48.265     12.44  19614
# 8   00:21:48.755     21.72  20116
# 9   00:21:49.247     10.81  20618
# 10  00:21:49.737     20.53  21120
# 11  00:21:50.280     12.64  21622
# 12  00:21:50.778     20.55  22124
# 13  00:21:51.266     29.23  22626
# 14  00:21:51.785     14.60  23128
# 15  00:21:52.256     22.22  23630
# 16  00:21:52.759     12.14  24132
# 17  00:21:53.274     10.63  24634
# 18  00:21:53.790     12.89  25136
# 19  00:21:54.275     20.80  25638
# 20  00:21:54.797     19.49  26140
# 21  00:21:55.257     13.26  26642
# 22  00:21:55.794     19.17  27144
# 23  00:21:56.300     12.70  27646
# 24  00:21:56.796     17.54  28148
# 25  00:21:57.298     19.37  28650
# ...

# %%
df.drop('Mag', axis='columns')
# Out:
#        Timestamp Magnitude
# 0   00:21:44.740     12.73
# 1   00:21:45.249     12.89
# 2   00:21:45.751     11.24
# 3   00:21:46.223     12.68
# 4   00:21:46.730     13.66
# 5   00:21:47.266     22.93
# 6   00:21:47.774     12.59
# 7   00:21:48.265     12.44
# 8   00:21:48.755     21.72
# 9   00:21:49.247     10.81
# 10  00:21:49.737     20.53
# 11  00:21:50.280     12.64
# 12  00:21:50.778     20.55
# 13  00:21:51.266     29.23
# 14  00:21:51.785     14.60
# 15  00:21:52.256     22.22
# 16  00:21:52.759     12.14
# 17  00:21:53.274     10.63
# 18  00:21:53.790     12.89
# 19  00:21:54.275     20.80
# 20  00:21:54.797     19.49
# 21  00:21:55.257     13.26
# 22  00:21:55.794     19.17
# 23  00:21:56.300     12.70
# 24  00:21:56.796     17.54
# 25  00:21:57.298     19.37
# 26  00:21:57.789     13.08
# 27  00:21:58.290     16.74
# 28  00:21:58.789     13.10
# 29  00:21:59.299     19.50
# 30  00:21:59.805     24.59
# 31  00:22:00.316     12.99
# 32  00:22:00.816     12.53
# ...

# %%
df['Magnitude'] = pd.to_numeric(df.Magnitude)

# %%
df.plot(y='Magnitude', figsize=(9,6))
# Out:
# <Axes: >
