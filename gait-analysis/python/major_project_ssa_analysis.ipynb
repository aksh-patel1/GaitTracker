# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from scipy.stats import pearsonr

# %% [markdown]
# ##Loading the data

# %% [markdown]
# ###Loading sub11

# %% [markdown]
# ####Abnormal

# %%
df_s11_ab1 = pd.read_csv("drive/MyDrive/project_csv_data/sub11_Abnorm_1.csv")
df_s11_ab1.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0       65558  0.98  0.02 -0.05  9.85
# 1       65580  0.98 -0.04 -0.10  9.83
# 2       65602  0.86 -0.26 -0.11  9.05
# 3       65624  0.86 -0.25 -0.14  9.04
# 4       65646  0.94  0.05 -0.09  9.50

# %%
df_s11_ab1.shape
# Out:
# (378, 5)

# %%
df_s11_ab2 = pd.read_csv("drive/MyDrive/project_csv_data/sub11_Abnorm_2.csv")
df_s11_ab2.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0        8178  0.92 -0.13 -0.19  9.45
# 1      158200  0.90  0.07 -0.05  9.09
# 2      158222  0.89 -0.16 -0.10  9.14
# 3      158244  0.93  0.04 -0.06  9.30
# 4      158266  0.90 -0.00 -0.05  9.05

# %%
df_s11_ab2.shape
# Out:
# (388, 5)

# %% [markdown]
# ####Normal

# %%
df_s11_n1 = pd.read_csv("drive/MyDrive/project_csv_data/sub11_Norm_1.csv")
df_s11_n1.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      217556  0.85 -0.05 -0.11  8.58
# 1      217578  0.86 -0.04 -0.10  8.65
# 2      217600  0.88 -0.13 -0.03  8.94
# 3      217622  0.85 -0.08  0.02  8.53
# 4      217644  0.83 -0.12 -0.01  8.42

# %%
df_s11_n1.mag.plot()
# Out:
# <Axes: >

# %%
df_s11_n1.shape
# Out:
# (285, 5)

# %%
df_s11_n2 = pd.read_csv("drive/MyDrive/project_csv_data/sub11_Norm_2.csv")
df_s11_n2.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      248048  0.90  0.01  0.10  9.02
# 1      248070  0.90  0.03  0.14  9.15
# 2      248092  0.85 -0.07  0.09  8.60
# 3      248114  0.87 -0.14  0.03  8.85
# 4      248136  0.87 -0.10 -0.05  8.73

# %%
df_s11_n2.shape
# Out:
# (301, 5)

# %%
df_s11_n3 = pd.read_csv("drive/MyDrive/project_csv_data/sub11_Norm_3.csv")
df_s11_n3.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      276054  0.88  0.02 -0.09  8.85
# 1      276076  0.90 -0.06 -0.06  9.01
# 2      276098  0.87 -0.06 -0.10  8.79
# 3      276120  0.86 -0.06 -0.12  8.75
# 4      276142  0.87 -0.10 -0.17  8.89

# %%
df_s11_n3.shape
# Out:
# (306, 5)

# %% [markdown]
# ###Loading sub12

# %% [markdown]
# ####Abnormal

# %%
df_s12_ab1 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Abnorm_1.csv")
df_s12_ab1.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      391620  0.92  0.38  0.09  9.95
# 1      391642  0.82  0.32 -0.05  8.80
# 2      391664  0.84 -0.09  0.09  8.45
# 3      391686  0.88 -0.31  0.23  9.65
# 4      391708  0.80 -0.23  0.18  8.56

# %%
df_s12_ab2 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Abnorm_2.csv")
df_s12_ab2.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      427150  0.81 -0.15  0.03  8.26
# 1      427172  0.84 -0.21  0.01  8.67
# 2      427194  0.85 -0.22  0.01  8.77
# 3      427216  0.83 -0.21  0.01  8.58
# 4      427238  0.81 -0.19 -0.02  8.33

# %% [markdown]
# ####Normal

# %%
df_s12_n1 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Norm_1.csv")
df_s12_n1.head()
# Out:
#    timestamps    ax    ay    az    mag
# 0      456410  0.84 -0.27 -0.07   8.86
# 1      456432  0.81 -0.33 -0.16   8.85
# 2      456454  0.76 -0.34 -0.22   8.58
# 3      456476  0.85 -0.29 -0.16   9.10
# 4      456498  0.99 -0.23 -0.10  10.25

# %%
df_s12_n2 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Norm_2.csv")
df_s12_n2.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      487650  0.82 -0.37  0.01  8.99
# 1      487672  0.77 -0.36 -0.03  8.51
# 2      487694  0.76 -0.35 -0.05  8.41
# 3      487716  0.81 -0.32 -0.06  8.69
# 4      487738  0.83 -0.28 -0.05  8.75

# %%
df_s12_n3 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Norm_3.csv")
df_s12_n3.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      508066  0.83 -0.24 -0.07  8.68
# 1      508044  0.96 -0.11 -0.05  9.67
# 2      508088  0.80 -0.38 -0.08  8.86
# 3      508110  0.84 -0.29 -0.05  8.92
# 4      508132  0.84 -0.20 -0.05  8.67

# %%
df_s12_n3 = pd.read_csv("drive/MyDrive/project_csv_data/sub12_Norm_3.csv")
df_s12_n3.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      508066  0.83 -0.24 -0.07  8.68
# 1      508044  0.96 -0.11 -0.05  9.67
# 2      508088  0.80 -0.38 -0.08  8.86
# 3      508110  0.84 -0.29 -0.05  8.92
# 4      508132  0.84 -0.20 -0.05  8.67

# %% [markdown]
# ###Loading sub13

# %% [markdown]
# ####Left leg

# %%
df_s13_lld_l1 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Left_1.csv")
df_s13_lld_l1.head()
# Out:
#    timestamps    ax    ay    az    mag
# 0      560448  0.92  0.07  0.19   9.37
# 1      560470  1.09  0.33 -0.05  11.38
# 2      560492  0.85  0.18 -0.18   8.85
# 3      560514  0.88 -0.18 -0.02   9.01
# 4      560536  0.89 -0.24  0.00   9.21

# %%
df_s13_lld_l1.shape
# Out:
# (242, 5)

# %%
df_s13_lld_l2 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Left_2.csv")
df_s13_lld_l2.head()
# Out:
#    timestamps    ax    ay    az    mag
# 0      572834  0.85 -0.17 -0.27   9.10
# 1      572856  0.94  0.24 -0.25  10.05
# 2      572878  0.95  0.48 -0.21  10.84
# 3      572900  0.89  0.48 -0.11  10.16
# 4      572922  0.90  0.05 -0.03   9.05

# %%
df_s13_lld_l3 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Left_3.csv")
df_s13_lld_l3.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      624050  0.89  0.08 -0.09  8.93
# 1      624072  0.89  0.08 -0.09  9.03
# 2      624094  0.89  0.08 -0.08  8.98
# 3      624116  0.88  0.09 -0.10  8.95
# 4      624138  0.89  0.08 -0.11  8.96

# %% [markdown]
# ####Right Leg

# %%
df_s13_lld_r1 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Right_1.csv")
df_s13_lld_r1.head()
# Out:
#    timestamps    ax    ay    az    mag
# 0      706572  0.87 -0.27 -0.36   9.80
# 1      706594  0.70 -0.25 -0.23   7.78
# 2      706616  0.63  0.08 -0.12   6.43
# 3      706638  0.66  0.24 -0.20   7.30
# 4      706660  1.81  0.65 -0.88  21.19

# %%
df_s13_lld_r2 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Right_2.csv")
df_s13_lld_r2.head()
# Out:
#    timestamps    ax    ay    az    mag
# 0      692932  0.93  0.03 -0.57  10.97
# 1      692954  1.87 -0.11 -0.67  19.95
# 2      692976  1.21 -1.03 -0.30  16.15
# 3      692910  0.52 -0.28 -0.17   6.18
# 4      692998  0.45 -1.20  0.25  13.04

# %%
df_s13_lld_r3 = pd.read_csv("drive/MyDrive/project_csv_data/sub13_LLD_Right_3.csv")
df_s13_lld_r3.head()
# Out:
#    timestamps    ax    ay    az   mag
# 0      672670  0.88 -0.18 -0.06  9.00
# 1      672648  0.88 -0.19 -0.07  9.06
# 2      672692  0.88 -0.18 -0.07  9.05
# 3      672714  0.88 -0.18 -0.09  9.06
# 4      672736  0.90 -0.20 -0.11  9.24

# %%
# Left
accel_l1 = df_s13_lld_l1.mag
accel_l1.index /= 100

accel_l2 = df_s13_lld_l2.mag
accel_l2.index /= 100

accel_l3 = df_s13_lld_l3.mag
accel_l3.index /= 100

# Right
accel_r1 = df_s13_lld_r1.mag
accel_r1.index /= 100

accel_r2 = df_s13_lld_r2.mag
accel_r2.index /= 100

accel_r3 = df_s13_lld_r3.mag
accel_r3.index /= 100

# %%
accel_l1.plot(color='red', figsize=(15,6))
accel_r1.plot(color='blue')

plt.title("Subject #13 LLD left Vs Right")
plt.legend(["Left leg", "Right leg"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
plt.show()

# %% [markdown]
# ##Similarity between two Signals

# %% [markdown]
# ###Cross-correlation

# %% [markdown]
# ####Intra-subject

# %% [markdown]
# ######sub11

# %% [markdown]
# ######Normal

# %%
acc_s11_n1 = df_s11_n1.mag
acc_s11_n1.index /= 100

acc_s11_n2 = df_s11_n2.mag
acc_s11_n2.index /= 100

acc_s11_n3 = df_s11_n3.mag
acc_s11_n3.index /= 100

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import correlate


acc_s11_n1 = acc_s11_n1 - acc_s11_n1.mean()
acc_s11_n2 = acc_s11_n2 - acc_s11_n2.mean()

# Calculate cross-correlation
cross_corr = correlate(acc_s11_n1, acc_s11_n2, mode='same')

print("Cross-correlation between sub1-n1 and sub1-n2: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s11_n1, label='Signal: sub1-norm-1')
plt.plot(acc_s11_n2, label='Signal sub1-norm-2')
plt.title('sub1-norm-1 vs sub1-norm-2')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s11_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s11_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-n2:  [ -57.13035307  -61.29204285  -51.24100683  -16.00527415    1.98739801
#    67.33272143   95.07447724   94.11768074  121.06106877  152.38680967
#   130.15400837   86.51651769   87.67218545   86.09681386   70.60514809
#    62.41240119   50.68051349   27.65246886    9.87301615   -5.16401015
#   -87.3620071  -124.97303107 -105.15625372 -132.7581762  -192.25115404
#  -193.93138461 -130.02880301 -125.57833107 -156.76086376 -132.06893587
#   -79.68638027  -20.45341629   -3.00078827   13.22257748   68.73375032
#   184.05425717  286.33687014  257.1960694   259.11342062  260.61476549
#   280.63707825  432.86214759  274.09627569   54.3705596   -19.81585462
#   -65.43938565  -72.89891581 -121.30358769 -148.07083844 -133.51018456
#  -113.89088064 -186.14869305 -247.9693805  -219.23826624 -169.44880519
#  -187.84804954 -147.79648097  -93.93003426  -96.99328365  -20.6159325
#    47.62283058   74.50886593  130.31229867  223.01055751  243.79898335
# ...

# %%
print(cross_corr.mean())
# Out:
# -0.75781957125373

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  285.000000
# mean    -0.757820
# std    211.708847
# min   -346.203389
# 25%   -167.778365
# 50%    -47.836780
# 75%    138.379112
# max    714.325401

# %%
acc_s11_n3 = acc_s11_n3 - acc_s11_n3.mean()

# Calculate cross-correlation
cross_corr = correlate(acc_s11_n1, acc_s11_n3, mode='same')

print("Cross-correlation between sub1-n1 and sub1-n3: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s11_n1, label='Signal: sub1-norm-1')
plt.plot(acc_s11_n3, label='Signal sub1-norm-3')
plt.title('sub1-norm-1 vs sub1-norm-2')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s11_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s11_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-n3:  [-1.07979180e+02 -1.35711090e+02 -1.13228552e+02 -4.62586420e+01
#  -5.01181277e+01 -1.39308400e+01  4.72098744e+01  2.35016817e+01
#   5.14216476e+01  8.69550750e+01  5.34681259e+01  5.23933930e+01
#   8.56434676e+01  1.02338341e+02  7.35769014e+01  6.21656488e+01
#   2.71961089e+01  5.62095982e+01  7.87646803e+01 -3.03744868e+00
#  -4.10868526e+01 -5.65850356e+01 -2.95087046e+01 -6.77846134e+01
#  -1.49442385e+02 -1.07603611e+02 -7.57025322e+01 -1.06308345e+02
#  -1.00699374e+02 -1.03050317e+02 -5.28750000e+01 -4.46990496e+01
#  -7.32256279e+01 -5.57629610e+01  2.61880434e+00  1.35488205e+02
#   2.23614167e+02  1.40071896e+02  2.35906601e+01  4.98604216e+01
#   5.36041415e+01  7.99831888e+01  2.17247378e+02  3.29964607e+02
#   3.75443055e+02  1.62654048e+02 -4.16834730e+01 -1.11980923e+02
#  -1.12092048e+02 -1.34712337e+02 -1.76132512e+02 -1.60116539e+02
#  -1.20516182e+02 -4.83583518e+01 -5.70881133e+01 -9.98856456e+01
# ...

# %%
print(cross_corr.mean())
# Out:
# 0.30408093728991875

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  285.000000
# mean     0.304081
# std    143.658300
# min   -280.773211
# 25%   -103.050317
# 50%    -20.407484
# 75%     78.764680
# max    478.181240

# %% [markdown]
# ######Abnormal

# %%
acc_s11_ab1 = df_s11_ab1.mag
acc_s11_ab1.index /= 100

acc_s11_ab2 = df_s11_ab2.mag
acc_s11_ab2.index /= 100

# %%
acc_s11_ab1 = acc_s11_ab1 - acc_s11_ab1.mean()
acc_s11_ab2 = acc_s11_ab2 - acc_s11_ab2.mean()

# Calculate cross-correlation
cross_corr = correlate(acc_s11_ab1, acc_s11_ab2, mode='same')

print("Cross-correlation between sub1-ab1 and sub1-ab2: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s11_ab1, label='Signal: sub1-Abnorm-1')
plt.plot(acc_s11_ab2, label='Signal sub1-Abnorm-2')
plt.title('sub11-ab1 Vs sub11-ab2')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s11_ab1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s11_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-ab1 and sub1-ab2:  [ 9.84507975e+01  1.16018601e+02  1.04753216e+02  5.29641317e+01
#   4.64590158e+00 -3.61956783e+01 -6.72616973e+01 -5.10480843e+01
#  -4.08886775e+01 -6.77519256e+01 -9.49334423e+00  8.27586013e+00
#   2.47711835e+01  4.75129131e+01  1.44283290e+02  1.81759276e+02
#   1.31063015e+02  1.01339934e+01 -4.34504416e+01 -5.50359395e+01
#  -3.13325114e+01 -1.50750632e+01 -2.73919862e+01  1.08132816e+01
#  -4.02345502e+00 -2.38818870e+01 -5.80051440e+01  1.63722041e+01
#  -7.85939290e+01 -1.20379667e+02 -4.31427390e+01  1.75543536e+02
#   8.69102534e+01  1.15387976e+01  1.14203575e+02  2.09379938e+02
#   1.30274501e+02  1.87993782e+02  1.93144427e+02  7.09657564e+01
#   1.26445752e+02  1.99640530e+02  1.61176582e+02  2.42431416e+02
#   3.04790562e+02  8.31076942e+01 -1.16478433e+00 -5.67438623e+01
#  -1.48994628e+02 -1.45388362e+02 -6.38275740e+01  4.34177985e+01
#   9.14236731e+01  1.74620271e+00 -1.65303037e+01  5.65334299e+01
# ...

# %%
print(cross_corr.mean())
# Out:
# 4.676894314600808

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  378.000000
# mean     4.676894
# std     95.664310
# min   -248.632577
# 25%    -52.116434
# 50%     -1.850391
# 75%     52.973099
# max    421.980661

# %% [markdown]
# ######Normal Vs Abnormal

# %%
# Calculate cross-correlation
cross_corr = correlate(acc_s11_n1, acc_s11_ab1, mode='same')

print("Cross-correlation between sub1-n1 and sub1-ab1: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s11_n1, label='Signal: sub1-norm-1')
plt.plot(acc_s11_n3, label='Signal sub1-Abnorm-1')
plt.title('sub1 Normal Vs Abnormal')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s11_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s11_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-ab1:  [ -72.44698613  -85.8216151  -149.80487923  -72.43160065  -48.46270677
#  -129.80312263 -121.76714634  -86.36235321  -80.58632319  -97.92071431
#   -64.07669967  -73.18162513  -86.2495002   119.03865643  272.88255709
#   189.19869731  168.70855846  191.30301569  157.38193786  202.18802155
#   190.05930007  138.29047377  170.96929287  124.76360572  -18.77255312
#   -98.8057114  -189.63061669 -204.50214147 -179.26296133 -110.47028436
#   -38.82854893  -16.56794945  -29.62845112  -79.78687003 -110.15035369
#  -134.28232991 -103.60555572  -50.01092804  -50.39969118    2.08627069
#   135.85405615  178.0731323   220.39909238  273.39633577  247.15500799
#   217.0944104   202.60336996  185.50335439  121.14995587   90.76558765
#   141.37031641   37.47814566  -94.24855943 -173.08323713 -291.58079893
#  -294.86229247 -247.48548835 -254.26809108 -237.71803732 -229.9909452
#  -229.79174912 -196.9533294  -113.93279492  -38.44403215  -15.50708774
# ...

# %%
print(cross_corr.mean())
# Out:
# -3.9336478754781337

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  285.000000
# mean    -3.933648
# std    141.649423
# min   -294.862292
# 25%   -103.605556
# 50%    -28.977881
# 75%     93.388147
# max    438.241913

# %% [markdown]
# ######sub12

# %% [markdown]
# ######Normal

# %%
acc_s12_n1 = df_s12_n1.mag
acc_s12_n1.index /= 100

acc_s12_n2 = df_s12_n2.mag
acc_s12_n2.index /= 100

acc_s12_n3 = df_s12_n3.mag
acc_s12_n3.index /= 100

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import correlate


acc_s12_n1 = acc_s12_n1 - acc_s12_n1.mean()
acc_s12_n2 = acc_s12_n2 - acc_s12_n2.mean()

# Calculate cross-correlation
cross_corr = correlate(acc_s12_n1, acc_s12_n2, mode='same')

print("Cross-correlation between sub1-n1 and sub1-n2: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s12_n1, label='Signal: sub12-norm-1')
plt.plot(acc_s12_n2, label='Signal sub12-norm-2')
plt.title('sub12-norm-1 vs sub12-norm-2')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s12_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s12_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-n2:  [-147.79568573 -144.99145253 -151.13777574 -153.73339039 -179.14833062
#  -188.00136822 -154.82827609 -143.50318797  -87.64280511 -130.78161853
#  -130.8221511    78.06171476  212.8890621   101.55990732   22.05740746
#    75.47165799  149.83903202  256.16602732  185.3018667    65.85688231
#    43.47755105   83.96572312   53.97326705  -32.49135211  -87.69918789
#  -114.52571785 -155.37886741 -179.16538449 -183.01422016 -227.03424783
#  -347.41081    -421.45837038 -331.59894242 -298.6823232  -239.18412073
#   -31.15228     169.44165335  235.0766008   465.76881841  667.77992644
#   635.67031856  715.85829505  818.70654441  479.86415391  -22.62435956
#    50.01984641   96.02782872 -178.10320838 -337.8992551  -291.96943749
#  -247.45714061 -257.5858182  -140.91517094 -137.28170109 -279.37561208
#  -357.7551937  -268.94379665 -218.19849176 -285.56189357 -280.71634009
#  -122.31754583   28.89352346   78.50585635   69.22888971  146.36560198
# ...

# %%
print(cross_corr.mean())
# Out:
# 4.621335579764898

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                  0
# count   251.000000
# mean      4.621336
# std     328.997522
# min    -504.885481
# 25%    -236.740866
# 50%     -91.621015
# 75%     164.523188
# max    1304.853579

# %% [markdown]
# ######Abnormal

# %%
acc_s12_ab1 = df_s12_ab1.mag
acc_s12_ab1.index /= 100

acc_s12_ab2 = df_s12_ab2.mag
acc_s12_ab2.index /= 100

# %%
acc_s12_ab1 = acc_s12_ab1 - acc_s12_ab1.mean()
acc_s12_ab2 = acc_s12_ab2 - acc_s12_ab2.mean()

# Calculate cross-correlation
cross_corr = correlate(acc_s12_ab1, acc_s12_ab2, mode='same')

print("Cross-correlation between sub1-ab1 and sub1-ab2: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s12_ab1, label='Signal: sub1-Abnorm-1')
plt.plot(acc_s12_ab2, label='Signal sub1-Abnorm-2')
plt.title('sub12-ab1 Vs sub12-ab2')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s12_ab1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s12_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-ab1 and sub1-ab2:  [ 8.11178124e+00 -2.05366879e+01 -5.76343820e+01 -1.55084967e+01
#   3.47537368e+01  9.03436067e+00  4.60805451e+00  3.24453186e+01
#   2.96447854e+01 -7.06849326e+00 -1.79400929e+01  3.87133051e+00
#   2.89304905e+00 -5.92255653e+00  1.29482521e+01  1.46842120e+01
#  -5.63331851e+00  1.17901675e+01  6.68452531e+01  3.61410216e+01
#  -5.79122903e+01 -7.05058273e+01 -3.45333519e+01 -2.67433394e+01
#  -2.59867655e+01 -5.25191268e+00  1.28414891e+01  3.26895018e+01
#   3.67218941e+01  1.40035655e+00 -2.62550787e+00  5.15234546e+01
#   6.55987565e+01  2.73468062e+01  7.51186771e+00 -3.25964185e+01
#  -3.23607919e+01  2.65498392e+00 -3.92337160e+01 -1.00526858e+02
#  -6.90535886e+01 -3.44186296e+01 -4.41211438e+01 -2.01061826e+01
#   2.03950374e+01 -1.40437288e+01 -3.24807115e+01  5.03768056e+01
#   8.31689981e+01  3.13310287e+00 -2.67522499e+01  3.49513414e+00
#  -1.17903674e+01 -2.72628040e+01 -2.24957495e+01 -3.03401697e+01
# ...

# %%
print(cross_corr.mean())
# Out:
# 3.2507292816679905

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  413.000000
# mean     3.250729
# std     70.709280
# min   -221.426189
# 25%    -37.608516
# 50%     -5.633319
# 75%     38.180306
# max    396.132563

# %% [markdown]
# ######Normal Vs Abnormal

# %%
# Calculate cross-correlation
cross_corr = correlate(acc_s12_n1, acc_s12_ab1, mode='same')

print("Cross-correlation between sub1-n1 and sub1-ab1: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s12_n1, label='Signal: sub1-norm-1')
plt.plot(acc_s12_n3, label='Signal sub1-Abnorm-1')
plt.title('sub12 Normal Vs Abnormal')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s12_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s12_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-ab1:  [ -53.4845588   -88.85551831   -2.6528732   -24.63883772  -35.54761573
#   -39.46172812 -115.97638272 -137.41653108  -86.94484242   -7.20561024
#    -1.23110423  -10.33370747   47.67141864  112.20671714  102.82202119
#    33.91642713    6.7002589    92.00089235  151.72248319   47.90721984
#   -66.95760064  -46.4798487   -15.52057012 -110.27907856 -249.53784412
#  -244.35167341  -81.10846216  -38.30891815 -170.08179189 -124.9505239
#    30.69189686   12.02440288  -20.10694413  111.84822798   32.65156962
#   -69.80651723  -37.84607039   40.67400877  146.94661793  198.25865445
#    26.46962911   78.7418546   383.11472546  259.86945279    3.9695749
#    78.16299084  128.63357092  -21.32502669 -102.6863996  -171.55146614
#  -107.66587729   39.58619522  105.43157729 -115.99013108 -135.73086653
#    28.33367211   -5.4884239   -61.82179482    4.72938048   50.23686056
#    37.08748247   64.01299203   86.8894753    40.6181494   -20.48868526
# ...

# %%
print(cross_corr.mean())
# Out:
# -3.9308655798845273

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  251.000000
# mean    -3.930866
# std    110.503309
# min   -286.405802
# 25%    -72.812055
# 50%     -6.274904
# 75%     73.967245
# max    383.114725

# %% [markdown]
# ####Inter-subject

# %% [markdown]
# #####sub11 vs sub12

# %%
# Calculate cross-correlation
cross_corr = correlate(acc_s11_n1, acc_s12_n1, mode='same')

print("Cross-correlation between sub1-n1 and sub1-ab1: ", cross_corr)



# Plot signals and cross-correlation
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(acc_s12_n1, label='Signal: sub11-norm-1')
plt.plot(acc_s12_n3, label='Signal sub12-norm-1')
plt.title('sub11 Normal Vs sub12 Normal')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(acc_s11_n1.index, cross_corr)
plt.title('Cross-Correlation')
plt.xlabel('Time Lag')

# plt.subplot(3, 1, 3)
# plt.plot(acc_s12_n1.index, normalized_cross_corr)
# plt.title('Normalized Cross-Correlation')
# plt.xlabel('Time Lag')
# plt.ylabel('Similarity')

plt.tight_layout()
plt.show()
# Out:
# Cross-correlation between sub1-n1 and sub1-ab1:  [-158.26510667 -161.55639918 -147.23297207 -150.73306874 -151.13167719
#   -74.61380911    9.33419809   53.21950418   40.57562246   41.09019159
#    75.67430368   79.79597571   75.1501701     8.06177488  -32.98912775
#    57.98107407   89.59682721   14.90104392   77.22439211  118.4181108
#     1.72390331 -110.73170606  -98.78716693  -27.11476198  -63.46883524
#  -156.72907869 -164.85982351 -153.89361524 -100.23592151  -49.40714041
#   -98.49536791  -94.1166672    69.03408383   85.44787416  -22.90424926
#    44.77581741  170.36476871   93.31922365   18.94837555   79.70403147
#    14.69084365  -17.46506481   55.12261998  222.27335084  400.1981752
#   286.26564412  131.8873406    97.03133204   13.89238179  -50.46881039
#   -62.14440555  -95.85401697 -139.97165239 -180.00691115 -187.07135716
#   -92.73316191  -36.77987899  -64.71357231  -75.85439189  -55.3765111
#    13.97232101  -32.25645285 -106.80827074 -117.15577804  -83.26385513
# ...

# %%
print(cross_corr.mean())
# Out:
# -2.6413598859888183

# %%
cross_corr = pd.DataFrame(cross_corr)
cross_corr.describe()
# Out:
#                 0
# count  285.000000
# mean    -2.641360
# std    129.532688
# min   -256.411776
# 25%    -87.865342
# 50%    -20.151677
# 75%     57.981074
# max    433.132870

# %% [markdown]
# ##SSA

# %% [markdown]
# ###Setting up SSA

# %%
import numpy as np
from numpy import pi
import matplotlib.pyplot as plt
import pandas as pd

# Fiddle with figure settings here:
plt.rcParams['figure.figsize'] = (20,6)
plt.rcParams['font.size'] = 20
plt.rcParams['image.cmap'] = 'plasma'
plt.rcParams['axes.linewidth'] = 2
# Set the default colour cycle (in case someone changes it...)
from cycler import cycler
cols = plt.get_cmap('tab10').colors
plt.rcParams['axes.prop_cycle'] = cycler(color=cols)

# A simple little 2D matrix plotter, excluding x and y labels.
def plot_2d(m, title=""):
    plt.imshow(m)
    plt.xticks([])
    plt.yticks([])
    plt.title(title)

# %%
class SSA(object):

    __supported_types = (pd.Series, np.ndarray, list)

    def __init__(self, tseries, L, save_mem=True):
        """
        Decomposes the given time series with a singular-spectrum analysis. Assumes the values of the time series are
        recorded at equal intervals.

        Parameters
        ----------
        tseries : The original time series, in the form of a Pandas Series, NumPy array or list.
        L : The window length. Must be an integer 2 <= L <= N/2, where N is the length of the time series.
        save_mem : Conserve memory by not retaining the elementary matrices. Recommended for long time series with
            thousands of values. Defaults to True.

        Note: Even if an NumPy array or list is used for the initial time series, all time series returned will be
        in the form of a Pandas Series or DataFrame object.
        """

        # Tedious type-checking for the initial time series
        if not isinstance(tseries, self.__supported_types):
            raise TypeError("Unsupported time series object. Try Pandas Series, NumPy array or list.")

        # Checks to save us from ourselves
        self.N = len(tseries)
        if not 2 <= L <= self.N/2:
            raise ValueError("The window length must be in the interval [2, N/2].")

        self.L = L
        self.orig_TS = pd.Series(tseries)
        self.K = self.N - self.L + 1

        # Embed the time series in a trajectory matrix
        self.X = np.array([self.orig_TS.values[i:L+i] for i in range(0, self.K)]).T

        # Decompose the trajectory matrix
        self.U, self.Sigma, VT = np.linalg.svd(self.X)
        self.d = np.linalg.matrix_rank(self.X)

        self.TS_comps = np.zeros((self.N, self.d))

        if not save_mem:
            # Construct and save all the elementary matrices
            self.X_elem = np.array([ self.Sigma[i]*np.outer(self.U[:,i], VT[i,:]) for i in range(self.d) ])

            # Diagonally average the elementary matrices, store them as columns in array.
            for i in range(self.d):
                X_rev = self.X_elem[i, ::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]

            self.V = VT.T
        else:
            # Reconstruct the elementary matrices without storing them
            for i in range(self.d):
                X_elem = self.Sigma[i]*np.outer(self.U[:,i], VT[i,:])
                X_rev = X_elem[::-1]
                self.TS_comps[:,i] = [X_rev.diagonal(j).mean() for j in range(-X_rev.shape[0]+1, X_rev.shape[1])]

            self.X_elem = "Re-run with save_mem=False to retain the elementary matrices."

            # The V array may also be very large under these circumstances, so we won't keep it.
            self.V = "Re-run with save_mem=False to retain the V matrix."

        # Calculate the w-correlation matrix.
        self.calc_wcorr()

    def components_to_df(self, n=0):
        """
        Returns all the time series components in a single Pandas DataFrame object.
        """
        if n > 0:
            n = min(n, self.d)
        else:
            n = self.d

        # Create list of columns - call them F0, F1, F2, ...
        cols = ["F{}".format(i) for i in range(n)]
        return pd.DataFrame(self.TS_comps[:, :n], columns=cols, index=self.orig_TS.index)


    def reconstruct(self, indices):
        """
        Reconstructs the time series from its elementary components, using the given indices. Returns a Pandas Series
        object with the reconstructed time series.

        Parameters
        ----------
        indices: An integer, list of integers or slice(n,m) object, representing the elementary components to sum.
        """
        if isinstance(indices, int): indices = [indices]

        ts_vals = self.TS_comps[:,indices].sum(axis=1)
        return pd.Series(ts_vals, index=self.orig_TS.index)

    def calc_wcorr(self):
        """
        Calculates the w-correlation matrix for the time series.
        """

        # Calculate the weights
        w = np.array(list(np.arange(self.L)+1) + [self.L]*(self.K-self.L-1) + list(np.arange(self.L)+1)[::-1])

        def w_inner(F_i, F_j):
            return w.dot(F_i*F_j)

        # Calculated weighted norms, ||F_i||_w, then invert.
        F_wnorms = np.array([w_inner(self.TS_comps[:,i], self.TS_comps[:,i]) for i in range(self.d)])
        F_wnorms = F_wnorms**-0.5

        # Calculate Wcorr.
        self.Wcorr = np.identity(self.d)
        for i in range(self.d):
            for j in range(i+1,self.d):
                self.Wcorr[i,j] = abs(w_inner(self.TS_comps[:,i], self.TS_comps[:,j]) * F_wnorms[i] * F_wnorms[j])
                self.Wcorr[j,i] = self.Wcorr[i,j]

    def plot_wcorr(self, min=None, max=None):
        """
        Plots the w-correlation matrix for the decomposed time series.
        """
        if min is None:
            min = 0
        if max is None:
            max = self.d

        if self.Wcorr is None:
            self.calc_wcorr()

        ax = plt.imshow(self.Wcorr)
        plt.xlabel(r"$\tilde{F}_i$")
        plt.ylabel(r"$\tilde{F}_j$")
        plt.colorbar(ax.colorbar, fraction=0.045)
        ax.colorbar.set_label("$W_{i,j}$")
        plt.clim(0,1)

        # For plotting purposes:
        if max == self.d:
            max_rnge = self.d-1
        else:
            max_rnge = max

        plt.xlim(min-0.5, max_rnge+0.5)
        plt.ylim(max_rnge+0.5, min-0.5)

# %% [markdown]
# ###sub11

# %% [markdown]
# ####Observing the norm vs abnorm patterns

# %%
def extract_series(subject, walk, norm="Norm"):
    walk_dict = { 1 : "t", 2 : "wlk_15"}
    file_path = "drive/MyDrive/project_csv_data/"
    file = "sub{}_{}_{}.csv".format(subject, norm, walk)
    file_path += file
    walk = pd.read_csv(file_path)
    # cols = ["userAcceleration.x", "userAcceleration.y", "userAcceleration.z"]
    accel = walk.mag

    # Convert acceleration values to z-scores.
    accel = (accel - accel.mean())/accel.std()

    # Convert index to units of seconds
    accel.index /= 100

    # Perform the SSA
    start = 0 # seconds, not samples
    end = 3 # seconds
    window = 140 # samples
    return SSA(accel.loc[start:end], window)

# %%
sub11_norm_1_ssa = extract_series(11, 1, 'Norm')
sub11_norm_2_ssa = extract_series(11, 2, 'Norm')
sub11_norm_3_ssa = extract_series(11, 3, 'Norm')

# %%
sub11_norm_1_ssa.reconstruct(slice(0,4)).plot(color='red', figsize=(7,6))
sub11_norm_2_ssa.reconstruct(slice(0,4)).plot(color='blue')
sub11_norm_3_ssa.reconstruct(slice(0,4)).plot(color='green')
plt.xlim(0,1.5)
plt.ylim(-2,2)
plt.title("Subject #11 Walk 'Signature'")
plt.legend(["Walk #1", "Walk #2", "Walk #3"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Z-Score")
plt.show()

# %%
sub11_ab_1_ssa = extract_series(11, 1, 'Abnorm')
sub11_ab_2_ssa = extract_series(11, 2, 'Abnorm')

# %%
sub11_ab_1_ssa.reconstruct(slice(0,4)).plot(color='red', figsize=(7,6))
sub11_ab_2_ssa.reconstruct(slice(0,4)).plot(color='blue')

plt.xlim(0,2)
plt.ylim(-1.5,1.5)
plt.title("Subject #11 Abnorm")
plt.legend(["walk #1", "walk #2"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Z-Score")
plt.show()

# %%
sub11_ab_1_ssa.reconstruct(slice(0,4)).plot(color='red', figsize=(7,6))
sub11_norm_1_ssa.reconstruct(slice(0,4)).plot(color='blue')

plt.xlim(0,1.5)
plt.ylim(-2,2)
plt.title("Subject #11 Norm Vs Abnorm")
plt.legend(["Sub #11 Abnorm", "Sub #11 Norm"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Z-Score")
plt.show()

# %%
sub11_ab_2_ssa.reconstruct(slice(0,4)).plot(color='red', figsize=(12,6))
sub11_norm_2_ssa.reconstruct(slice(0,4)).plot(color='blue')

plt.xlim(0,1.8)
plt.ylim(-2,2)
plt.title("Subject #11 Norm Vs Abnorm")
plt.legend(["Sub #11 Abnorm", "Sub #11 Norm"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Z-Score")
plt.show()

# %% [markdown]
# ####Normal SSA ploting

# %%
accel_n1 = df_s11_n1.mag


accel_ab1 = df_s11_ab1.mag

# %%
window1, window2 = 120, 150
ssa_n1 = SSA(accel_n1, window1)
ssa_ab1 = SSA(accel_ab1, window2)

# %%
ssa_n1.reconstruct(0).plot()
ssa_n1.reconstruct([1,2]).plot()
ssa_n1.reconstruct([3,4]).plot()
ssa_n1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: First Three Groups")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
legend = [r"$\tilde{{F}}^{{({0})}}$".format(i) for i in range(3)] + ["Original TS"]
plt.legend(legend)

# %%
ssa_n1.reconstruct(slice(0,5)).plot()
ssa_n1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: Low-Frequency Periodicity")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
plt.xlim(0,2.5)
plt.ylim(3, 25)
# Out:
# (3.0, 25.0)

# %% [markdown]
# ####Abnormal SSA ploting

# %%
ssa_ab1.reconstruct(0).plot()
ssa_ab1.reconstruct([1,2]).plot()
ssa_ab1.reconstruct([3,4]).plot()
ssa_ab1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: First Three Groups")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
legend = [r"$\tilde{{F}}^{{({0})}}$".format(i) for i in range(3)] + ["Original TS"]
plt.legend(legend)

# %%
ssa_ab1.reconstruct(slice(0,5)).plot()
ssa_ab1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: Low-Frequency Periodicity")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
plt.xlim(0,2.5)
plt.ylim(3, 25)
# Out:
# (3.0, 25.0)

# %% [markdown]
# ###sub12

# %%
accel12_n1 = df_s12_n1.mag
accel12_n1.index /= 100

accel12_ab1 = df_s12_ab1.mag
accel12_ab1.index /= 100

# %%
window1, window2 = 120, 150
ssa_n1 = SSA(accel_l1, window1)
ssa_ab1 = SSA(accel_r1, window2)

# %% [markdown]
# ####Normal SSA ploting

# %% [markdown]
# ####Abnormal SSA ploting

# %% [markdown]
# ###sub13

# %% [markdown]
# ####Observing the Left Vs Right LLD pattern

# %%
def extract_lld_series(subject, walk, isLeft="Left"):
    walk_dict = { 1 : "t", 2 : "wlk_15"}
    file_path = "drive/MyDrive/project_csv_data/"
    file = "sub{}_LLD_{}_{}.csv".format(subject, isLeft, walk)
    file_path += file
    walk = pd.read_csv(file_path)
    # cols = ["userAcceleration.x", "userAcceleration.y", "userAcceleration.z"]
    accel = walk.mag

    # Convert acceleration values to z-scores.
    accel = (accel - accel.mean())/accel.std()

    # Convert index to units of seconds
    accel.index /= 100

    # Perform the SSA
    start = 0 # seconds, not samples
    end = 3 # seconds
    window = 120 # samples
    return SSA(accel.loc[start:end], window)

# %%
ssa13_lld_l1 = extract_lld_series(13, 1, 'Left')
ssa13_lld_l2 = extract_lld_series(13, 2, 'Left')
ssa13_lld_l3 = extract_lld_series(13, 3, 'Left')

ssa13_lld_r1 = extract_lld_series(13, 1, 'Right')
ssa13_lld_r2 = extract_lld_series(13, 2, 'Right')
ssa13_lld_r3 = extract_lld_series(13, 3, 'Right')

# %%
ssa13_lld_l1.reconstruct(slice(0,4)).plot(color='red', figsize=(14,6))
ssa13_lld_r1.reconstruct(slice(0,4)).plot(color='blue')

plt.xlim(0,2)
plt.ylim(-2,2)
plt.title("Subject #13 Left Vs Right LLD")
plt.legend(["Sub #13 Left", "Sub #13 Right"])
plt.xlabel(r"$t$ (s)")
plt.ylabel("Z-Score")
plt.show()

# %%
window = 120
ssa_lld_l1 = SSA(accel_l1, window)
ssa_lld_r1 = SSA(accel_r1, window)

# %% [markdown]
# #####Left leg SSA ploting

# %%
ssa_lld_l1.reconstruct(0).plot()
ssa_lld_l1.reconstruct([1,2]).plot()
ssa_lld_l1.reconstruct([3,4]).plot()
ssa_lld_l1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: First Three Groups")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
legend = [r"$\tilde{{F}}^{{({0})}}$".format(i) for i in range(3)] + ["Original TS"]
plt.legend(legend)

# %%
ssa_lld_l1.reconstruct(slice(0,5)).plot()
ssa_lld_l1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: Low-Frequency Periodicity")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
plt.xlim(0,2.5)
plt.ylim(3, 25)
# Out:
# (3.0, 25.0)

# %% [markdown]
# #####Right leg SSA ploting

# %%
ssa_lld_r1.reconstruct(0).plot()
ssa_lld_r1.reconstruct([1,2]).plot()
ssa_lld_r1.reconstruct([3,4]).plot()
ssa_lld_r1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: First Three Groups")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
legend = [r"$\tilde{{F}}^{{({0})}}$".format(i) for i in range(3)] + ["Original TS"]
plt.legend(legend)

# %%
ssa_lld_r1.reconstruct(slice(0,5)).plot()
ssa_lld_r1.orig_TS.plot(alpha=0.4)
plt.title("Walking Time Series: Low-Frequency Periodicity")
plt.xlabel(r"$t$ (s)")
plt.ylabel("Acceleration (m/s^2)")
plt.xlim(0,2.5)
plt.ylim(3, 25)
# Out:
# (3.0, 25.0)
